# %% [markdown]
# # Step 0: Install dependencies

# %%
# !pip install azure-identity==1.15.0
# !pip install azureml-fsspec==1.3.1
# !pip install azureml-sdk==1.55.0
# !pip install azure-ai-ml==1.15.0
# !pip install mltable==1.6.1
# Out:
# Collecting azure-identity==1.15.0
#   Downloading azure_identity-1.15.0-py3-none-any.whl.metadata (75 kB)
#      ---------------------------------------- 0.0/75.4 kB ? eta -:--:--
#      ---------- ----------------------------- 20.5/75.4 kB ? eta -:--:--
#      -------------------------------------- - 71.7/75.4 kB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 75.4/75.4 kB 1.4 MB/s eta 0:00:00
# Collecting azure-core<2.0.0,>=1.23.0 (from azure-identity==1.15.0)
#   Downloading azure_core-1.30.2-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: cryptography>=2.5 in c:\users\51922\anaconda3\lib\site-packages (from azure-identity==1.15.0) (42.0.2)
# Collecting msal<2.0.0,>=1.24.0 (from azure-identity==1.15.0)
#   Downloading msal-1.29.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions<2.0.0,>=0.3.0 (from azure-identity==1.15.0)
#   Downloading msal_extensions-1.2.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: requests>=2.21.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-identity==1.15.0) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-identity==1.15.0) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-identity==1.15.0) (4.9.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\51922\anaconda3\lib\site-packages (from cryptography>=2.5->azure-identity==1.15.0) (1.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\51922\anaconda3\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal<2.0.0,>=1.24.0->azure-identity==1.15.0) (2.4.0)
# Collecting portalocker<3,>=1.4 (from msal-extensions<2.0.0,>=0.3.0->azure-identity==1.15.0)
#   Downloading portalocker-2.10.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pycparser in c:\users\51922\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity==1.15.0) (2.21)
# Requirement already satisfied: pywin32>=226 in c:\users\51922\anaconda3\lib\site-packages (from portalocker<3,>=1.4->msal-extensions<2.0.0,>=0.3.0->azure-identity==1.15.0) (305.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\51922\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity==1.15.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\51922\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity==1.15.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\51922\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity==1.15.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\51922\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity==1.15.0) (2024.2.2)
# Downloading azure_identity-1.15.0-py3-none-any.whl (164 kB)
#    ---------------------------------------- 0.0/164.7 kB ? eta -:--:--
#    ---------------------------------------- 164.7/164.7 kB 3.4 MB/s eta 0:00:00
# Downloading azure_core-1.30.2-py3-none-any.whl (194 kB)
#    ---------------------------------------- 0.0/194.3 kB ? eta -:--:--
#    --------------------------------------- 194.3/194.3 kB 12.3 MB/s eta 0:00:00
# Downloading msal-1.29.0-py3-none-any.whl (110 kB)
#    ---------------------------------------- 0.0/110.9 kB ? eta -:--:--
#    ---------------------------------------- 110.9/110.9 kB ? eta 0:00:00
# Downloading msal_extensions-1.2.0-py3-none-any.whl (19 kB)
# Downloading portalocker-2.10.0-py3-none-any.whl (18 kB)
# Installing collected packages: portalocker, azure-core, msal, msal-extensions, azure-identity
# Successfully installed azure-core-1.30.2 azure-identity-1.15.0 msal-1.29.0 msal-extensions-1.2.0 portalocker-2.10.0
# Collecting azureml-fsspec==1.3.1
#   Downloading azureml_fsspec-1.3.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting azureml-dataprep<5.2.0a,>=5.1.0a (from azureml-fsspec==1.3.1)
#   Downloading azureml_dataprep-5.1.6-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: fsspec<=2023.10.0,>=2021.6.1 in c:\users\51922\anaconda3\lib\site-packages (from azureml-fsspec==1.3.1) (2023.10.0)
# Requirement already satisfied: pytz in c:\users\51922\anaconda3\lib\site-packages (from azureml-fsspec==1.3.1) (2023.3.post1)
# Collecting azureml-dataprep-native<42.0.0,>=41.0.0 (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1)
#   Downloading azureml_dataprep_native-41.0.0-cp311-cp311-win_amd64.whl.metadata (1.4 kB)
# Collecting azureml-dataprep-rslex~=2.22.2dev0 (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1)
#   Downloading azureml_dataprep_rslex-2.22.2-cp311-cp311-win_amd64.whl.metadata (1.7 kB)
# Requirement already satisfied: cloudpickle<3.0.0,>=1.1.0 in c:\users\51922\anaconda3\lib\site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (2.2.1)
# Requirement already satisfied: azure-identity>=1.7.0 in c:\users\51922\anaconda3\lib\site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (1.15.0)
# Requirement already satisfied: jsonschema in c:\users\51922\anaconda3\lib\site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (4.19.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in c:\users\51922\anaconda3\lib\site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (6.0.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (1.30.2)
# Requirement already satisfied: cryptography>=2.5 in c:\users\51922\anaconda3\lib\site-packages (from azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (42.0.2)
# Requirement already satisfied: msal<2.0.0,>=1.24.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (1.29.0)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (1.2.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\51922\anaconda3\lib\site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\51922\anaconda3\lib\site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\51922\anaconda3\lib\site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\51922\anaconda3\lib\site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (0.10.6)
# Requirement already satisfied: requests>=2.21.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (4.9.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\51922\anaconda3\lib\site-packages (from cryptography>=2.5->azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (1.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\51922\anaconda3\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal<2.0.0,>=1.24.0->azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (2.4.0)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\51922\anaconda3\lib\site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (2.10.0)
# Requirement already satisfied: pycparser in c:\users\51922\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (2.21)
# Requirement already satisfied: pywin32>=226 in c:\users\51922\anaconda3\lib\site-packages (from portalocker<3,>=1.4->msal-extensions<2.0.0,>=0.3.0->azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (305.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\51922\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\51922\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\51922\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\51922\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-fsspec==1.3.1) (2024.2.2)
# Downloading azureml_fsspec-1.3.1-py3-none-any.whl (16 kB)
# Downloading azureml_dataprep-5.1.6-py3-none-any.whl (252 kB)
#    ---------------------------------------- 0.0/252.4 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/252.4 kB 1.3 MB/s eta 0:00:01
#    --------------------------- ------------ 174.1/252.4 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 252.4/252.4 kB 2.6 MB/s eta 0:00:00
# Downloading azureml_dataprep_native-41.0.0-cp311-cp311-win_amd64.whl (893 kB)
#    ---------------------------------------- 0.0/893.3 kB ? eta -:--:--
#    ----------------- ---------------------- 399.4/893.3 kB 8.3 MB/s eta 0:00:01
#    --------------------------------------- 893.3/893.3 kB 11.2 MB/s eta 0:00:00
# Downloading azureml_dataprep_rslex-2.22.2-cp311-cp311-win_amd64.whl (18.3 MB)
#    ---------------------------------------- 0.0/18.3 MB ? eta -:--:--
#    - -------------------------------------- 0.8/18.3 MB 25.1 MB/s eta 0:00:01
#    -- ------------------------------------- 1.0/18.3 MB 22.0 MB/s eta 0:00:01
#    -- ------------------------------------- 1.0/18.3 MB 22.0 MB/s eta 0:00:01
#    -- ------------------------------------- 1.0/18.3 MB 22.0 MB/s eta 0:00:01
#    -- ------------------------------------- 1.0/18.3 MB 22.0 MB/s eta 0:00:01
#    -- ------------------------------------- 1.0/18.3 MB 22.0 MB/s eta 0:00:01
#    -- ------------------------------------- 1.0/18.3 MB 22.0 MB/s eta 0:00:01
#    -- ------------------------------------- 1.0/18.3 MB 22.0 MB/s eta 0:00:01
#    -- ------------------------------------- 1.0/18.3 MB 22.0 MB/s eta 0:00:01
#    -- ------------------------------------- 1.0/18.3 MB 22.0 MB/s eta 0:00:01
#    -- ------------------------------------- 1.0/18.3 MB 22.0 MB/s eta 0:00:01
#    -- ------------------------------------- 1.0/18.3 MB 22.0 MB/s eta 0:00:01
#    ---- ----------------------------------- 2.1/18.3 MB 3.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.1/18.3 MB 3.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.1/18.3 MB 3.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.1/18.3 MB 3.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.1/18.3 MB 3.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.1/18.3 MB 3.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.1/18.3 MB 3.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.1/18.3 MB 3.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.1/18.3 MB 3.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.1/18.3 MB 3.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.1/18.3 MB 3.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.1/18.3 MB 3.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.2/18.3 MB 1.9 MB/s eta 0:00:09
#    ------ --------------------------------- 3.1/18.3 MB 2.7 MB/s eta 0:00:06
#    ------ --------------------------------- 3.1/18.3 MB 2.7 MB/s eta 0:00:06
#    ------ --------------------------------- 3.1/18.3 MB 2.7 MB/s eta 0:00:06
#    ------ --------------------------------- 3.1/18.3 MB 2.7 MB/s eta 0:00:06
#    ------ --------------------------------- 3.1/18.3 MB 2.7 MB/s eta 0:00:06
#    ------ --------------------------------- 3.1/18.3 MB 2.7 MB/s eta 0:00:06
#    ------ --------------------------------- 3.1/18.3 MB 2.7 MB/s eta 0:00:06
#    ------ --------------------------------- 3.1/18.3 MB 2.7 MB/s eta 0:00:06
#    ------ --------------------------------- 3.1/18.3 MB 2.7 MB/s eta 0:00:06
#    --------- ------------------------------ 4.2/18.3 MB 2.6 MB/s eta 0:00:06
#    --------- ------------------------------ 4.2/18.3 MB 2.6 MB/s eta 0:00:06
#    --------- ------------------------------ 4.2/18.3 MB 2.6 MB/s eta 0:00:06
#    ---------- ----------------------------- 4.6/18.3 MB 2.6 MB/s eta 0:00:06
#    ----------- ---------------------------- 5.2/18.3 MB 2.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 5.2/18.3 MB 2.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 5.2/18.3 MB 2.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 5.2/18.3 MB 2.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 5.2/18.3 MB 2.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 5.2/18.3 MB 2.9 MB/s eta 0:00:05
#    ------------- -------------------------- 6.3/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 6.3/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 6.3/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 6.3/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 6.3/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 6.3/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 6.3/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 6.3/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 6.3/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 6.3/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 6.3/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 6.3/18.3 MB 3.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 7.3/18.3 MB 2.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 7.3/18.3 MB 2.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 7.3/18.3 MB 2.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 7.6/18.3 MB 2.7 MB/s eta 0:00:04
#    ------------------ --------------------- 8.4/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------------ --------------------- 8.4/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------------ --------------------- 8.4/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------------ --------------------- 8.4/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------------ --------------------- 8.4/18.3 MB 3.0 MB/s eta 0:00:04
#    ------------------- -------------------- 8.8/18.3 MB 2.9 MB/s eta 0:00:04
#    -------------------- ------------------- 9.4/18.3 MB 3.0 MB/s eta 0:00:03
#    -------------------- ------------------- 9.4/18.3 MB 3.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 10.5/18.3 MB 3.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 10.5/18.3 MB 3.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 10.5/18.3 MB 3.2 MB/s eta 0:00:03
#    ------------------------- -------------- 11.5/18.3 MB 3.7 MB/s eta 0:00:02
#    ------------------------- -------------- 11.5/18.3 MB 3.7 MB/s eta 0:00:02
#    ------------------------- -------------- 11.5/18.3 MB 3.7 MB/s eta 0:00:02
#    ------------------------- -------------- 11.5/18.3 MB 3.7 MB/s eta 0:00:02
#    ------------------------- -------------- 11.5/18.3 MB 3.7 MB/s eta 0:00:02
#    ------------------------- -------------- 11.6/18.3 MB 3.4 MB/s eta 0:00:02
#    --------------------------- ------------ 12.6/18.3 MB 4.2 MB/s eta 0:00:02
#    --------------------------- ------------ 12.6/18.3 MB 4.2 MB/s eta 0:00:02
#    --------------------------- ------------ 12.7/18.3 MB 4.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.6/18.3 MB 4.8 MB/s eta 0:00:01
#    -------------------------------- ------- 14.7/18.3 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 14.7/18.3 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 14.7/18.3 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 14.7/18.3 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 14.7/18.3 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 14.7/18.3 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 14.7/18.3 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 14.7/18.3 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 14.7/18.3 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 14.7/18.3 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 14.7/18.3 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.7/18.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.7/18.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.7/18.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.7/18.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.7/18.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.7/18.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.7/18.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.7/18.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.7/18.3 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 16.8/18.3 MB 3.6 MB/s eta 0:00:01
#    -------------------------------------- - 17.8/18.3 MB 2.8 MB/s eta 0:00:01
#    -------------------------------------- - 17.8/18.3 MB 2.8 MB/s eta 0:00:01
#    -------------------------------------- - 17.8/18.3 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 18.3/18.3 MB 2.7 MB/s eta 0:00:00
# Installing collected packages: azureml-dataprep-rslex, azureml-dataprep-native, azureml-dataprep, azureml-fsspec
# Successfully installed azureml-dataprep-5.1.6 azureml-dataprep-native-41.0.0 azureml-dataprep-rslex-2.22.2 azureml-fsspec-1.3.1
# Collecting azureml-sdk==1.55.0
#   Downloading azureml_sdk-1.55.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting azureml-core~=1.55.0 (from azureml-sdk==1.55.0)
#   Downloading azureml_core-1.55.0.post2-py3-none-any.whl.metadata (3.2 kB)
# Collecting azureml-dataset-runtime~=1.55.0 (from azureml-dataset-runtime[fuse]~=1.55.0->azureml-sdk==1.55.0)
#   Downloading azureml_dataset_runtime-1.55.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting azureml-train-core~=1.55.0 (from azureml-sdk==1.55.0)
#   Downloading azureml_train_core-1.55.0-py3-none-any.whl.metadata (1.7 kB)
# INFO: pip is looking at multiple versions of azureml-sdk to determine which version is compatible with other requirements. This could take a while.
# ERROR: Ignored the following versions that require a different python version: 1.10.0 Requires-Python >=3.5,<3.9; 1.10.0.post1 Requires-Python >=3.5,<3.9; 1.10.0.post2 Requires-Python >=3.5,<3.9; 1.11.0 Requires-Python >=3.5,<3.9; 1.11.0.post1 Requires-Python >=3.5,<3.9; 1.11.0.post2 Requires-Python >=3.5,<3.9; 1.12.0 Requires-Python >=3.5,<3.9; 1.12.0.post1 Requires-Python >=3.5,<3.9; 1.12.0.post2 Requires-Python >=3.5,<3.9; 1.13.0 Requires-Python >=3.5,<3.9; 1.13.0.post1 Requires-Python >=3.5,<3.9; 1.13.0.post2 Requires-Python >=3.5,<3.9; 1.14.0 Requires-Python >=3.5,<3.9; 1.14.0.post1 Requires-Python >=3.5,<3.9; 1.14.0.post2 Requires-Python >=3.5,<3.9; 1.15.0 Requires-Python >=3.5,<3.9; 1.15.0.post1 Requires-Python >=3.5,<3.9; 1.16.0 Requires-Python >=3.5,<3.9; 1.16.0.post1 Requires-Python >=3.5,<3.9; 1.16.0.post2 Requires-Python >=3.5,<3.9; 1.17.0 Requires-Python >=3.5,<3.9; 1.17.0.post1 Requires-Python >=3.5,<3.9; 1.18.0 Requires-Python >=3.5,<3.9; 1.18.0.post1 Requires-Python >=3.5,<3.9; 1.18.0.post2 Requires-Python >=3.5,<3.9; 1.18.0.post3 Requires-Python >=3.5,<3.9; 1.18.0.post4 Requires-Python >=3.5,<3.9; 1.19.0 Requires-Python >=3.5,<3.9; 1.2.0 Requires-Python >=3.5,<3.9; 1.2.0.post1 Requires-Python >=3.5,<3.9; 1.2.0.post2 Requires-Python >=3.5,<3.9; 1.2.0.post3 Requires-Python >=3.5,<3.9; 1.20.0 Requires-Python >=3.5,<3.9; 1.20.0.post1 Requires-Python >=3.5,<3.9; 1.21.0 Requires-Python >=3.5,<3.9; 1.21.0.post1 Requires-Python >=3.5,<3.9; 1.21.0.post2 Requires-Python >=3.5,<3.9; 1.22.0 Requires-Python >=3.5,<3.9; 1.22.0.post1 Requires-Python >=3.5,<3.9; 1.23.0 Requires-Python >=3.5,<3.9; 1.23.0.post1 Requires-Python >=3.5,<3.9; 1.24.0 Requires-Python >=3.5,<3.9; 1.24.0.post1 Requires-Python >=3.5,<3.9; 1.24.0.post2 Requires-Python >=3.5,<3.9; 1.25.0 Requires-Python >=3.5,<3.9; 1.25.0.post1 Requires-Python >=3.5,<3.9; 1.26.0 Requires-Python >=3.5,<3.9; 1.26.0.post1 Requires-Python >=3.5,<3.9; 1.27.0 Requires-Python >=3.5,<3.9; 1.27.0.post1 Requires-Python >=3.5,<3.9; 1.28.0 Requires-Python >=3.5,<3.9; 1.28.0.post1 Requires-Python >=3.5,<3.9; 1.29.0 Requires-Python >=3.6,<3.9; 1.29.0.post1 Requires-Python >=3.6,<3.9; 1.3.0 Requires-Python >=3.5,<3.9; 1.3.0.post1 Requires-Python >=3.5,<3.9; 1.3.0.post2 Requires-Python >=3.5,<3.9; 1.30.0 Requires-Python >=3.6,<3.9; 1.31.0 Requires-Python >=3.6,<3.9; 1.32.0 Requires-Python >=3.6,<3.9; 1.33.0 Requires-Python >=3.6,<3.9; 1.33.0.post1 Requires-Python >=3.6,<3.9; 1.34.0 Requires-Python >=3.6,<3.9; 1.35.0 Requires-Python >=3.6,<3.9; 1.36.0 Requires-Python >=3.6,<3.9; 1.37.0 Requires-Python >=3.6,<3.9; 1.38.0 Requires-Python >=3.6,<3.9; 1.38.0.post2 Requires-Python >=3.6,<3.9; 1.38.0.post3 Requires-Python >=3.6,<3.9; 1.39.0 Requires-Python >=3.6,<3.9; 1.4.0 Requires-Python >=3.5,<3.9; 1.4.0.post1 Requires-Python >=3.5,<3.9; 1.4.0.post2 Requires-Python >=3.5,<3.9; 1.40.0 Requires-Python >=3.6,<3.9; 1.41.0 Requires-Python >=3.6,<3.9; 1.42.0 Requires-Python >=3.6,<3.9; 1.42.0.post1 Requires-Python >=3.6,<3.9; 1.43.0 Requires-Python >=3.6,<3.9; 1.44.0 Requires-Python >=3.6,<3.9; 1.45.0 Requires-Python >=3.6,<3.10; 1.46.0 Requires-Python >=3.6,<3.10; 1.47.0 Requires-Python >=3.6,<3.10; 1.48.0 Requires-Python >=3.7,<3.10; 1.49.0 Requires-Python >=3.7,<3.11; 1.49.0.post1 Requires-Python >=3.7,<3.11; 1.5.0 Requires-Python >=3.5,<3.9; 1.5.0.post1 Requires-Python >=3.5,<3.9; 1.5.0.post2 Requires-Python >=3.5,<3.9; 1.5.0.post3 Requires-Python >=3.5,<3.9; 1.5.0.post4 Requires-Python >=3.5,<3.9; 1.50.0 Requires-Python >=3.7,<3.11; 1.51.0 Requires-Python >=3.7,<3.11; 1.51.0.post1 Requires-Python >=3.7,<3.11; 1.52.0 Requires-Python >=3.7,<3.11; 1.53.0 Requires-Python >=3.7,<3.11; 1.53.2 Requires-Python >=3.7,<3.11; 1.54.0 Requires-Python >=3.7,<3.11; 1.54.0.post1 Requires-Python >=3.7,<3.11; 1.55.0 Requires-Python >=3.7,<3.11; 1.55.0.post1 Requires-Python <3.11,>=3.7; 1.56.0 Requires-Python <3.11,>=3.8; 1.6.0 Requires-Python >=3.5,<3.9; 1.6.0.post1 Requires-Python >=3.5,<3.9; 1.7.0 Requires-P ...
# ERROR: Could not find a version that satisfies the requirement azureml-train-automl-client~=1.55.0 (from azureml-sdk) (from versions: 1.0rc83, 1.0rc85, 1.0.76, 1.0.79, 1.0.81, 1.0.81.1, 1.0.83, 1.0.85, 1.0.85.1, 1.0.85.2, 1.0.85.3, 1.0.85.4, 1.1.0rc0, 1.1.1rc0, 1.1.2rc0, 1.1.5, 1.1.5.1, 1.1.5.2, 1.2.0, 1.3.0, 1.4.0, 1.5.0, 1.5.0.post1, 1.6.0, 1.6.0.post1, 1.7.0, 1.7.0.post1, 1.8.0, 1.9.0, 1.9.0.post1, 1.10.0, 1.11.0, 1.11.0.post1, 1.12.0, 1.12.0.post1, 1.12.0.post2, 1.13.0, 1.13.0.post1, 1.13.0.post2, 1.14.0, 1.14.0.post1, 1.15.0, 1.15.0.post1, 1.16.0, 1.17.0, 1.18.0)
# ERROR: No matching distribution found for azureml-train-automl-client~=1.55.0
# Collecting azure-ai-ml==1.15.0
#   Downloading azure_ai_ml-1.15.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-ai-ml==1.15.0) (6.0.1)
# Collecting msrest>=0.6.18 (from azure-ai-ml==1.15.0)
#   Downloading msrest-0.7.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-ai-ml==1.15.0) (1.30.2)
# Collecting azure-mgmt-core<2.0.0,>=1.3.0 (from azure-ai-ml==1.15.0)
#   Downloading azure_mgmt_core-1.4.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting marshmallow<4.0.0,>=3.5 (from azure-ai-ml==1.15.0)
#   Downloading marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-ai-ml==1.15.0) (4.19.2)
# Requirement already satisfied: tqdm<5.0.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-ai-ml==1.15.0) (4.65.0)
# Collecting strictyaml<2.0.0 (from azure-ai-ml==1.15.0)
#   Downloading strictyaml-1.7.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: colorama<0.5.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-ai-ml==1.15.0) (0.4.6)
# Requirement already satisfied: pyjwt<3.0.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-ai-ml==1.15.0) (2.4.0)
# Collecting azure-storage-blob<13.0.0,>=12.10.0 (from azure-ai-ml==1.15.0)
#   Downloading azure_storage_blob-12.20.0-py3-none-any.whl.metadata (26 kB)
# Collecting azure-storage-file-share<13.0.0 (from azure-ai-ml==1.15.0)
#   Downloading azure_storage_file_share-12.16.0-py3-none-any.whl.metadata (47 kB)
#      ---------------------------------------- 0.0/47.2 kB ? eta -:--:--
#      ---------------------------------------- 47.2/47.2 kB 2.3 MB/s eta 0:00:00
# Collecting azure-storage-file-datalake<13.0.0 (from azure-ai-ml==1.15.0)
#   Downloading azure_storage_file_datalake-12.15.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydash>=6.0.0 (from azure-ai-ml==1.15.0)
#   Downloading pydash-8.0.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting isodate (from azure-ai-ml==1.15.0)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting azure-common<2.0.0,>=1.1 (from azure-ai-ml==1.15.0)
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: typing-extensions<5.0.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-ai-ml==1.15.0) (4.9.0)
# Collecting opencensus-ext-azure<2.0.0 (from azure-ai-ml==1.15.0)
#   Downloading opencensus_ext_azure-1.1.13-py2.py3-none-any.whl.metadata (16 kB)
# Collecting opencensus-ext-logging<=0.1.1 (from azure-ai-ml==1.15.0)
#   Downloading opencensus_ext_logging-0.1.1-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: requests>=2.21.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-ml==1.15.0) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-ml==1.15.0) (1.16.0)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\51922\anaconda3\lib\site-packages (from azure-storage-blob<13.0.0,>=12.10.0->azure-ai-ml==1.15.0) (42.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\51922\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml==1.15.0) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\51922\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml==1.15.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\51922\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml==1.15.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\51922\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml==1.15.0) (0.10.6)
# Requirement already satisfied: packaging>=17.0 in c:\users\51922\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.5->azure-ai-ml==1.15.0) (23.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\51922\anaconda3\lib\site-packages (from msrest>=0.6.18->azure-ai-ml==1.15.0) (2024.2.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\51922\anaconda3\lib\site-packages (from msrest>=0.6.18->azure-ai-ml==1.15.0) (2.0.0)
# Requirement already satisfied: azure-identity<2.0.0,>=1.5.0 in c:\users\51922\anaconda3\lib\site-packages (from opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (1.15.0)
# Collecting opencensus<1.0.0,>=0.11.4 (from opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0)
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: psutil>=5.6.3 in c:\users\51922\anaconda3\lib\site-packages (from opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (5.9.0)
# Requirement already satisfied: python-dateutil>=2.6.0 in c:\users\51922\anaconda3\lib\site-packages (from strictyaml<2.0.0->azure-ai-ml==1.15.0) (2.8.2)
# Requirement already satisfied: msal<2.0.0,>=1.24.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-identity<2.0.0,>=1.5.0->opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (1.29.0)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-identity<2.0.0,>=1.5.0->opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\51922\anaconda3\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob<13.0.0,>=12.10.0->azure-ai-ml==1.15.0) (1.16.0)
# Collecting opencensus-context>=0.1.3 (from opencensus<1.0.0,>=0.11.4->opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0)
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\51922\anaconda3\lib\site-packages (from opencensus<1.0.0,>=0.11.4->opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\51922\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-ai-ml==1.15.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\51922\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-ai-ml==1.15.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\51922\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-ai-ml==1.15.0) (1.26.18)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\51922\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.18->azure-ai-ml==1.15.0) (3.2.2)
# Requirement already satisfied: pycparser in c:\users\51922\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob<13.0.0,>=12.10.0->azure-ai-ml==1.15.0) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\51922\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\51922\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\51922\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (1.23.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\51922\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (2.29.0)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\51922\anaconda3\lib\site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity<2.0.0,>=1.5.0->opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (2.10.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\51922\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\51922\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\51922\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (4.9)
# Requirement already satisfied: pywin32>=226 in c:\users\51922\anaconda3\lib\site-packages (from portalocker<3,>=1.4->msal-extensions<2.0.0,>=0.3.0->azure-identity<2.0.0,>=1.5.0->opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (305.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\51922\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure<2.0.0->azure-ai-ml==1.15.0) (0.4.8)
# Downloading azure_ai_ml-1.15.0-py3-none-any.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB 5.7 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/9.4 MB 5.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/9.4 MB 8.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/9.4 MB 8.3 MB/s eta 0:00:02
#    ------ --------------------------------- 1.5/9.4 MB 6.2 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.4 MB 7.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.4 MB 7.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.4 MB 7.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.4 MB 7.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.4 MB 7.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.4 MB 7.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.4 MB 7.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.4 MB 7.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.4 MB 7.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.4 MB 7.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.4 MB 7.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.4 MB 7.8 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.4 MB 7.8 MB/s eta 0:00:01
#    ------------- -------------------------- 3.1/9.4 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.4 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.4 MB 3.6 MB/s eta 0:00:02
#    -------------- ------------------------- 3.5/9.4 MB 3.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.4 MB 4.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.4 MB 4.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.4 MB 4.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.2/9.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.4 MB 4.3 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.4 MB 3.6 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.4 MB 3.6 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.4 MB 3.6 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.4 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.4 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.4 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.4 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.4 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.4 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.4 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.4 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.4 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.4 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.4 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.4 MB 3.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.4 MB 3.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.4 MB 3.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.4 MB 3.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.4 MB 3.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.4 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  9.3/9.4 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 3.4 MB/s eta 0:00:00
# Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Downloading azure_mgmt_core-1.4.0-py3-none-any.whl (27 kB)
# Downloading azure_storage_blob-12.20.0-py3-none-any.whl (392 kB)
#    ---------------------------------------- 0.0/392.2 kB ? eta -:--:--
#    ---------------------------------------- 392.2/392.2 kB ? eta 0:00:00
# Downloading azure_storage_file_datalake-12.15.0-py3-none-any.whl (254 kB)
#    ---------------------------------------- 0.0/254.3 kB ? eta -:--:--
#    --------------------------------------- 254.3/254.3 kB 15.3 MB/s eta 0:00:00
# Downloading azure_storage_file_share-12.16.0-py3-none-any.whl (268 kB)
#    ---------------------------------------- 0.0/268.8 kB ? eta -:--:--
#    --------------------------------------- 268.8/268.8 kB 17.2 MB/s eta 0:00:00
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.7 kB ? eta -:--:--
#    ---------------------------------------- 41.7/41.7 kB 2.1 MB/s eta 0:00:00
# Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.2 kB ? eta -:--:--
#    ---------------------------------------- 49.2/49.2 kB 2.6 MB/s eta 0:00:00
# Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.4 kB ? eta -:--:--
#    ---------------------------------------- 85.4/85.4 kB ? eta 0:00:00
# Downloading opencensus_ext_azure-1.1.13-py2.py3-none-any.whl (43 kB)
#    ---------------------------------------- 0.0/43.4 kB ? eta -:--:--
#    ---------------------------------------- 43.4/43.4 kB ? eta 0:00:00
# Downloading opencensus_ext_logging-0.1.1-py2.py3-none-any.whl (4.0 kB)
# Downloading pydash-8.0.1-py3-none-any.whl (101 kB)
#    ---------------------------------------- 0.0/101.5 kB ? eta -:--:--
#    ---------------------------------------- 101.5/101.5 kB ? eta 0:00:00
# Downloading strictyaml-1.7.3-py3-none-any.whl (123 kB)
#    ---------------------------------------- 0.0/123.9 kB ? eta -:--:--
#    ---------------------------------------- 123.9/123.9 kB ? eta 0:00:00
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
#    ---------------------------------------- 0.0/128.2 kB ? eta -:--:--
#    ---------------------------------------- 128.2/128.2 kB ? eta 0:00:00
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Installing collected packages: opencensus-context, azure-common, pydash, marshmallow, isodate, strictyaml, msrest, azure-storage-file-share, azure-storage-blob, azure-mgmt-core, opencensus, azure-storage-file-datalake, opencensus-ext-logging, opencensus-ext-azure, azure-ai-ml
# Successfully installed azure-ai-ml-1.15.0 azure-common-1.1.28 azure-mgmt-core-1.4.0 azure-storage-blob-12.20.0 azure-storage-file-datalake-12.15.0 azure-storage-file-share-12.16.0 isodate-0.6.1 marshmallow-3.21.3 msrest-0.7.1 opencensus-0.11.4 opencensus-context-0.1.3 opencensus-ext-azure-1.1.13 opencensus-ext-logging-0.1.1 pydash-8.0.1 strictyaml-1.7.3
# Collecting mltable==1.6.1
#   Downloading mltable-1.6.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: azureml-dataprep<5.2.0a,>=5.1.0a in c:\users\51922\anaconda3\lib\site-packages (from azureml-dataprep[parquet]<5.2.0a,>=5.1.0a->mltable==1.6.1) (5.1.6)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in c:\users\51922\anaconda3\lib\site-packages (from mltable==1.6.1) (6.0.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in c:\users\51922\anaconda3\lib\site-packages (from mltable==1.6.1) (4.19.2)
# Requirement already satisfied: msrest>=0.6.18 in c:\users\51922\anaconda3\lib\site-packages (from mltable==1.6.1) (0.7.1)
# Requirement already satisfied: azure-core!=1.22.0,<2.0.0,>=1.8.0 in c:\users\51922\anaconda3\lib\site-packages (from mltable==1.6.1) (1.30.2)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.0 in c:\users\51922\anaconda3\lib\site-packages (from mltable==1.6.1) (1.4.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in c:\users\51922\anaconda3\lib\site-packages (from mltable==1.6.1) (2.8.2)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in c:\users\51922\anaconda3\lib\site-packages (from mltable==1.6.1) (42.0.2)
# Requirement already satisfied: PyJWT<3.0.0 in c:\users\51922\anaconda3\lib\site-packages (from mltable==1.6.1) (2.4.0)
# Requirement already satisfied: pytz in c:\users\51922\anaconda3\lib\site-packages (from mltable==1.6.1) (2023.3.post1)
# Requirement already satisfied: requests>=2.21.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-core!=1.22.0,<2.0.0,>=1.8.0->mltable==1.6.1) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-core!=1.22.0,<2.0.0,>=1.8.0->mltable==1.6.1) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-core!=1.22.0,<2.0.0,>=1.8.0->mltable==1.6.1) (4.9.0)
# Requirement already satisfied: azureml-dataprep-native<42.0.0,>=41.0.0 in c:\users\51922\anaconda3\lib\site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataprep[parquet]<5.2.0a,>=5.1.0a->mltable==1.6.1) (41.0.0)
# Requirement already satisfied: azureml-dataprep-rslex~=2.22.2dev0 in c:\users\51922\anaconda3\lib\site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataprep[parquet]<5.2.0a,>=5.1.0a->mltable==1.6.1) (2.22.2)
# Requirement already satisfied: cloudpickle<3.0.0,>=1.1.0 in c:\users\51922\anaconda3\lib\site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataprep[parquet]<5.2.0a,>=5.1.0a->mltable==1.6.1) (2.2.1)
# Requirement already satisfied: azure-identity>=1.7.0 in c:\users\51922\anaconda3\lib\site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataprep[parquet]<5.2.0a,>=5.1.0a->mltable==1.6.1) (1.15.0)
# Requirement already satisfied: pyarrow>=0.17.0 in c:\users\51922\anaconda3\lib\site-packages (from azureml-dataprep[parquet]<5.2.0a,>=5.1.0a->mltable==1.6.1) (14.0.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\51922\anaconda3\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->mltable==1.6.1) (1.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\51922\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->mltable==1.6.1) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\51922\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->mltable==1.6.1) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\51922\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->mltable==1.6.1) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\51922\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->mltable==1.6.1) (0.10.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\51922\anaconda3\lib\site-packages (from msrest>=0.6.18->mltable==1.6.1) (2024.2.2)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\51922\anaconda3\lib\site-packages (from msrest>=0.6.18->mltable==1.6.1) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\51922\anaconda3\lib\site-packages (from msrest>=0.6.18->mltable==1.6.1) (2.0.0)
# Requirement already satisfied: msal<2.0.0,>=1.24.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataprep[parquet]<5.2.0a,>=5.1.0a->mltable==1.6.1) (1.29.0)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in c:\users\51922\anaconda3\lib\site-packages (from azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataprep[parquet]<5.2.0a,>=5.1.0a->mltable==1.6.1) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\51922\anaconda3\lib\site-packages (from cffi>=1.12->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->mltable==1.6.1) (2.21)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\51922\anaconda3\lib\site-packages (from pyarrow>=0.17.0->azureml-dataprep[parquet]<5.2.0a,>=5.1.0a->mltable==1.6.1) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\51922\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core!=1.22.0,<2.0.0,>=1.8.0->mltable==1.6.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\51922\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core!=1.22.0,<2.0.0,>=1.8.0->mltable==1.6.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\51922\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core!=1.22.0,<2.0.0,>=1.8.0->mltable==1.6.1) (1.26.18)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\51922\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.18->mltable==1.6.1) (3.2.2)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\51922\anaconda3\lib\site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataprep[parquet]<5.2.0a,>=5.1.0a->mltable==1.6.1) (2.10.0)
# Requirement already satisfied: pywin32>=226 in c:\users\51922\anaconda3\lib\site-packages (from portalocker<3,>=1.4->msal-extensions<2.0.0,>=0.3.0->azure-identity>=1.7.0->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataprep[parquet]<5.2.0a,>=5.1.0a->mltable==1.6.1) (305.1)
# Downloading mltable-1.6.1-py3-none-any.whl (189 kB)
#    ---------------------------------------- 0.0/189.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/189.4 kB ? eta -:--:--
#    ------------ -------------------------- 61.4/189.4 kB 656.4 kB/s eta 0:00:01
#    ---------------------------------------- 189.4/189.4 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: mltable
# Successfully installed mltable-1.6.1

# %% [markdown]
# # Step 1: Set up your workspace

# %%
from azure.identity import DefaultAzureCredential
from azure.ai.ml import MLClient

credential = DefaultAzureCredential()
ml_client = None
try:
    # Enter details of your Azure Machine Learning workspace
    subscription_id = "55eb0f0b-1af6-4de6-b7d9-b4b56e9a584c"
    resource_group = "dmc-group"
    workspace = "diego-workspace"
    ml_client = MLClient(credential, subscription_id, resource_group, workspace)
except Exception as ex:
    print(ex)

# %% [markdown]
# # Step 2: Data source and format

# %%
import mltable

paths = [
    {'file': './train_data/iris_dataset.csv'}
]

train_table = mltable.from_delimited_files(paths)
train_table.save('./train_data')
# Out:
# paths:
# - file: file://C:\Users\51922\Desktop\DMC MLE\LABS\AutoML_Azure\train_data\iris_dataset.csv
# transformations:
# - read_delimited:
#     delimiter: ','
#     empty_as_string: false
#     encoding: utf8
#     header: all_files_same_headers
#     include_path_column: false
#     infer_column_types: true
#     partition_size: 20971520
#     path_column: Path
#     support_multi_line: false
# type: mltable

# %% [markdown]
# # Step 3: Create a Compute Instance (If not exist)

# %%
# #Sign into Azure with Azure CLI
# !az login # lo ejecutas en consola de anaconda
# Out:
# ^C

# %%
ci_basic_name = "diego-basic-ci"
from azure.ai.ml.entities import ComputeInstance, AmlCompute
ci_basic = ComputeInstance(name=ci_basic_name, size="Standard_DS2_v2")
ml_client.begin_create_or_update(ci_basic).result()
# Out:
# ComputeInstance({'state': 'Running', 'last_operation': {'operation_name': 'Create', 'operation_time': '2024-06-26T03:44:46.027Z', 'operation_status': 'Succeeded', 'operation_trigger': 'User'}, 'os_image_metadata': <azure.ai.ml.entities._compute._image_metadata.ImageMetadata object at 0x000001F93D5A1150>, 'services': [{'display_name': 'Jupyter', 'endpoint_uri': 'https://diego-basic-ci.eastus.instances.azureml.ms/tree/'}, {'display_name': 'Jupyter Lab', 'endpoint_uri': 'https://diego-basic-ci.eastus.instances.azureml.ms/lab'}], 'type': 'computeinstance', 'created_on': '2024-06-26T03:44:38.441766+0000', 'provisioning_state': 'Succeeded', 'provisioning_errors': None, 'name': 'diego-basic-ci', 'description': None, 'tags': None, 'properties': {}, 'print_as_yaml': False, 'id': '/subscriptions/55eb0f0b-1af6-4de6-b7d9-b4b56e9a584c/resourceGroups/dmc-group/providers/Microsoft.MachineLearningServices/workspaces/diego-workspace/computes/diego-basic-ci', 'Resource__source_path': '', 'base_path': 'C:\\Users\\51922\\Desktop\\DMC MLE\\LABS\\AutoML_Azure', 'creation_context': None, 'serialize': <msrest.serialization.Serializer object at 0x000001F93D0A6950>, 'resource_id': None, 'location': 'eastus', 'size': 'Standard_DS2_v2', 'ssh_public_access_enabled': False, 'create_on_behalf_of': None, 'network_settings': <azure.ai.ml.entities._compute.compute.NetworkSettings object at 0x000001F93D0A8F50>, 'ssh_settings': <azure.ai.ml.entities._compute.compute_instance.ComputeInstanceSshSettings object at 0x000001F93D0A8A10>, 'schedules': None, 'identity': None, 'idle_time_before_shutdown': None, 'idle_time_before_shutdown_minutes': None, 'setup_scripts': None, 'enable_node_public_ip': True, 'enable_sso': True, 'enable_root_access': True, 'custom_applications': None, 'subnet': None})

# %% [markdown]
# # Step 4: Configure your experiment settings

# %%
from azure.ai.ml.constants import AssetTypes
from azure.ai.ml import automl, Input

# make an Input object for the training data
my_training_data_input = Input(
    type=AssetTypes.MLTABLE, path="./train_data"
)

# configure the classification job
classification_job = automl.classification(
    compute             = ci_basic_name,
    experiment_name     = "diego_experiment_python_3",
    training_data       = my_training_data_input,
    target_column_name  = "target",
    primary_metric      = "accuracy",
    n_cross_validations = 5,
    enable_model_explainability = True,
    tags                = {"dmc": "demo"}
)

# # Limits are all optional
# classification_job.set_limits(
#     timeout_minutes=600, 
#     trial_timeout_minutes=20, 
#     max_trials=2,
#     enable_early_termination=True,
# )

# # Training properties are optional
# classification_job.set_training(
#     blocked_training_algorithms=["logistic_regression"], 
#     enable_onnx_compatible_models=True
# )

# %% [markdown]
# # Step 5: Run experiment

# %%
# Submit the AutoML job
returned_job = ml_client.jobs.create_or_update(classification_job)

# Get the URL to monitor the job in Azure Machine Learning studio
print(f"Monitor your job at {returned_job.studio_url}")
# Out:
# Uploading train_data (0.0 MBs): 100%|##########| 3105/3105 [00:00<00:00, 4125.04it/s]
# Monitor your job at https://ml.azure.com/runs/salmon_beet_9b9vf4fvlq?wsid=/subscriptions/55eb0f0b-1af6-4de6-b7d9-b4b56e9a584c/resourcegroups/dmc-group/workspaces/diego-workspace&tid=034fc347-d9bf-4e0c-8aa1-0b0aa32f4188
